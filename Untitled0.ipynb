# %%
from google.colab import auth
auth.authenticate_user()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! git clone https://github.com/AI-nstein/hoppity.git
# Out:
# fatal: destination path 'hoppity' already exists and is not an empty directory.

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
# !nvidia-smi
# Out:
# Mon Jan  8 19:22:25 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 545.36                 Driver Version: 546.33       CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 4070        On  | 00000000:01:00.0  On |                  N/A |
# |  0%   48C    P5              21W / 200W |   2984MiB / 12282MiB |     34%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !docker run --gpus all nvcr.io/nvidia/k8s/cuda-sample:nbody nbody -gpu -benchmark
# Out:
# Run "nbody -benchmark [-numbodies=<numBodies>]" to measure performance.
# 	-fullscreen       (run n-body simulation in fullscreen mode)
# 	-fp64             (use double precision floating point values for simulation)
# 	-hostmem          (stores simulation data in host memory)
# 	-benchmark        (run benchmark to measure performance)
# 	-numbodies=<N>    (number of bodies (>= 1) to run in simulation)
# 	-device=<d>       (where d=0,1,2.... for the CUDA device to use)
# 	-numdevices=<i>   (where i=(number of CUDA devices > 0) to use for simulation)
# 	-compare          (compares simulation results running once on the default GPU and once on the CPU)
# 	-cpu              (run n-body simulation on the CPU)
# 	-tipsy=<file.bin> (load a tipsy model file for simulation)
#
# NOTE: The CUDA Samples are not meant for performance measurements. Results may vary when GPU Boost is enabled.
#
# > Windowed mode
# > Simulation data stored in video memory
# ...

# %%
# !pip uninstall torch-scatter torch-sparse torch-geometric torch-cluster  --y
# Out:
# WARNING: Skipping torch-scatter as it is not installed.
# WARNING: Skipping torch-sparse as it is not installed.
# Found existing installation: torch_geometric 2.4.0
# Uninstalling torch_geometric-2.4.0:
#   Successfully uninstalled torch_geometric-2.4.0
# WARNING: Skipping torch-cluster as it is not installed.

# %%
# !pip install torch-geometric
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.9/63.9 kB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 9.0 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# !conda install pytorch-scatter -c pyg -y
# !conda install pytorch-sparse -c pyg -y
# !conda install pytorch-cluster -c pyg -y
# !conda install pytorch-spline-conv -c pyg -y
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 23.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.11.0
#
#
#
# # All requested packages already installed.
#
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 23.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.11.0
#
#
#
# ## Package Plan ##
#
#   environment location: /home/spidi/anaconda3/envs/entorno_py310
#
#   added / updated specs:
#     - pytorch-sparse
#
#
# The following packages will be downloaded:
#
#     package                    |            build
# ...

# %%
import torch

# !pip install tqdm
# !pip install paramiko

# %%
# !pip install -e deps/torchext
# Out:
# Obtaining file:///mnt/d/hoppity/deps/torchext
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for torchext
# ...

# %%
# !pip install -e .
# Out:
# ERROR: hoppity is not a valid editable requirement. It should either be a path to a local project or a VCS URL (beginning with bzr+http, bzr+https, bzr+ssh, bzr+sftp, bzr+ftp, bzr+lp, bzr+file, git+http, git+https, git+ssh, git+git, git+file, hg+file, hg+http, hg+https, hg+ssh, hg+static-http, svn+ssh, svn+http, svn+https, svn+svn, svn+file).

# %%
# !npm install shift-parser
# !npm install ts-morph
# !npm install shift-spec-consumer
# Out:
# m#########⠂⠂⠂⠂⠂⠂⠂⠂⠂) ⠏ idealTree: timing idealTree Completed in 941ms
# up to date, audited 38 packages in 1s
#
# 5 packages are looking for funding
#   run `npm fund` for details
#
# found 0 vulnerabilities
# npm notice
# npm notice New patch version of npm available! 10.2.3 -> 10.2.5
# npm notice Changelog: https://github.com/npm/cli/releases/tag/v10.2.5
# npm notice Run npm install -g npm@10.2.5 to update!
# npm notice
# m#########⠂⠂⠂⠂⠂⠂⠂⠂⠂) ⠇ idealTree: timing idealTree Completed in 941ms
# up to date, audited 38 packages in 1s
#
# 5 packages are looking for funding
#   run `npm fund` for details
#
# found 0 vulnerabilities
# m#########⠂⠂⠂⠂⠂⠂⠂⠂⠂) ⠇ idealTree: timing idealTree Completed in 935ms
# up to date, audited 38 packages in 1s
#
# 5 packages are looking for funding
#   run `npm fund` for details
#
# found 0 vulnerabilities

# %%
# !du -sh drive/MyDrive/RCBI/dataset/cooked-full-fmt-shift_node/
# Out:
# 81M	drive/MyDrive/RCBI/dataset/cooked-full-fmt-shift_node/

# %%
# !tar -xzvf "drive/MyDrive/RCBI/cooked-one-diff.gz" -C "drive/MyDrive/RCBI/dataset/"
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# cooked-full-fmt-shift_node/03-01-2019:08_2811_SHIFT_0ExamFragment_gedit.txt
# cooked-full-fmt-shift_node/05-07-2019:17_3775_SHIFT_1projectCard_buggy.pkl
# cooked-full-fmt-shift_node/05-03-2019:03_3055_SHIFT_14UIActions_refs.npy
# cooked-full-fmt-shift_node/05-04-2019:04_923_SHIFT_2index_refs.npy
# cooked-full-fmt-shift_node/11-05-2018:08_472_SHIFT_0index_buggy.pkl
# cooked-full-fmt-shift_node/02-09-2019:17_3580_0Tabs_refs2.npy
# cooked-full-fmt-shift_node/10-02-2018:16_1899_SHIFT_0constants_buggy.pkl
# cooked-full-fmt-shift_node/01-09-2019:09_6026_SHIFT_2webpack.config_refs.npy
# cooked-full-fmt-shift_node/04-08-2019:21_4964_1templateNewRecipe_refs2.npy
# cooked-full-fmt-shift_node/10-02-2018:11_57_SHIFT_119ru_refs.npy
# cooked-full-fmt-shift_node/02-07-2019:19_2098_SHIFT_0App_refs.npy
# cooked-full-fmt-shift_node/10-03-2018:07_1370_SHIFT_197module_splice_test_fixed.pkl
# ...

# %%
# !tar xzf drive/MyDrive/RCBI/cooked-one-diff.gz -C drive/MyDrive/RCBI/
# Out:
# ^C

# %%
# !python hoppity/gtrans/data_process/split_train_test.py \
    -save_dir drive/MyDrive/RCBI/dataset/cooked-full-fmt-shift_node

# %%
# !cat drive/MyDrive/RCBI/cooked-full-fmt-shift_node/train.txt
# !cat drive/MyDrive/RCBI/cooked-full-fmt-shift_node/test.txt
# !cat drive/MyDrive/RCBI/cooked-full-fmt-shift_node/val.txt
# Out:
# 02-05-2019:13_2154_SHIFT_0Header
# 11-02-2018:08_796_SHIFT_3MyAddressBook
# 02-09-2019:09_1053_SHIFT_0message
# 01-05-2019:21_2958_SHIFT_0prisma-schema
# 02-12-2019:09_4945_SHIFT_58relative_date
# 01-04-2019:01_1269_SHIFT_0app

# %%
# !ls drive/MyDrive/RCBI/cooked-full-fmt-shift_node/
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#  12-01-2018:19_2533_SHIFT_0readings.controller_refs.npy
#  12-01-2018:19_2535_SHIFT_0Icon_fixed.pkl
#  12-01-2018:19_2593_SHIFT_46ChiJi_fixed.pkl
#  12-01-2018:19_275_SHIFT_0index_buggy.pkl
#  12-01-2018:19_2820_SHIFT_1index_gedit.txt
#  12-01-2018:19_2929_SHIFT_0store_fixed.pkl
#  12-01-2018:19_2990_SHIFT_0tableScroll_buggy.pkl
#  12-01-2018:19_3141_1header_refs2.npy
#  12-01-2018:19_3257_SHIFT_0webpack.common_fixed.pkl
#  12-01-2018:19_3289_0index_refs2.npy
#  12-01-2018:19_3312_SHIFT_3ContactUs_gedit.txt
#  12-01-2018:19_392_SHIFT_1tokenActions_buggy.pkl
#  12-01-2018:19_393_SHIFT_2contact_refs.npy
#  12-01-2018:19_427_SHIFT_2SimpleNavbar_refs.npy
#  12-01-2018:19_488_SHIFT_0app_gedit.txt
#  12-01-2018:19_596_SHIFT_0config_fixed.pkl
#  12-01-2018:20_1104_SHIFT_0script_buggy.pkl
#  12-01-2018:20_1442_SHIFT_2SignUpController_fixed.pkl
#  12-01-2018:20_1633_1order.router_refs2.npy
# ...

# %%
# !rm drive/MyDrive/RCBI/cooked-full-fmt-shift_node/test.txt
# !rm drive/MyDrive/RCBI/cooked-full-fmt-shift_node/train.txt
# !rm drive/MyDrive/RCBI/cooked-full-fmt-shift_node/val.txt

# %%
# !export data_name="test"
# !export cooked_root="drive/MyDrive/RCBI/cooked-full-fmt-shift_node/"
# !export save_dir="drive/MyDrive/RCBI/saved_dir/"
# !export target_model="drive/MyDrive/RCBI/one-diff-model.ckpt"
# !export eval_dump_folder="drive/MyDrive/RCBI/eval_dump_folder"

# !export CUDA_VISIBLE_DEVICES=0

# !python hoppity/gtrans/eval/eval.py \
	-target_model "drive/MyDrive/RCBI/one-diff-model.ckpt" \
	-data_root "drive/MyDrive/RCBI/cooked-full-fmt-shift_node/" \
	-data_name "test" \
	-save_dir "drive/MyDrive/RCBI/saved_dir/" \
  -eval_dump_folder "drive/MyDrive/RCBI/eval_dump_folder" \
	-iters_per_val 100 \
	-beam_size 3 \
	-batch_size 10 \
	-topk 3 \
	-gnn_type 's2v_multi' \
	-max_lv 4 \
	-max_modify_steps 1 \
	-gpu 0 \
	-resampling True \
	-comp_method "bilinear" \
	-bug_type True \
	-loc_acc True \
	-val_acc True \
	-output_all True \
	$@
# Out:
# use gpu indexed: 0
# loading HOPPITY from /content/hoppity
# ...

# %%
# !mv drive/MyDrive/RCBI/cooked-full-fmt-shift_node/vocab_04.npy drive/MyDrive/RCBI/cooked-full-fmt-shift_node/vocab_fixes.npy
# Out:
# mv: cannot stat 'drive/MyDrive/RCBI/cooked-full-fmt-shift_node/vocab_04.npy': No such file or directory
